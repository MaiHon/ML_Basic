# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# ### Non_normalized inputs

# %%
xy = np.array([[828.659973, 833.450012, 908100, 828.349976, 831.659973],
               [823.02002, 828.070007, 1828100, 821.655029, 828.070007],
               [819.929993, 824.400024, 1438100, 818.97998, 824.159973],
               [816, 820.958984, 1008100, 815.48999, 819.23999],
               [819.359985, 823, 1188100, 818.469971, 818.97998],
               [819, 823, 1198100, 816, 820.450012],
               [811.700012, 815.25, 1098100, 809.780029, 813.669983],
               [809.51001, 816.659973, 1398100, 804.539978, 809.559998]])

x_data = xy[:, 0:-1]
y_data = xy[:, [-1]]

# %%
# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape=[None, 4])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([4, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# Hypothesis
hypothesis = tf.matmul(X, W) + b

# Simplified cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# Launch the graph in a session.
with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())

        for step in range(101):
            cost_val, hy_val, _ = sess.run([cost, hypothesis, train], 
                                                         feed_dict={X: x_data, Y: y_data})
            print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)
# Out:
# WARNING:tensorflow:From /Users/mah/miniconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 0 Cost:  417078540000.0
# Prediction:
#  [[-454979.03]
#  [-915951.25]
#  [-720540.06]
#  [-505084.72]
#  [-595277.06]
#  [-600285.4 ]
#  [-550181.4 ]
#  [-700490.06]]
# 1 Cost:  4.58236e+26
# Prediction:
#  [[1.5099964e+13]
#  [3.0397776e+13]
#  [2.3912834e+13]
#  [1.6762770e+13]
#  [1.9755820e+13]
#  [1.9922101e+13]
#  [1.8259294e+13]
#  [2.3247712e+13]]
# 2 Cost:  inf
# Prediction:
#  [[-5.00508706e+20]
#  [-1.00757536e+21]
#  [-7.92623190e+20]
#  [-5.55624638e+20]
#  [-6.54833308e+20]
#  [-6.60344940e+20]
#  [-6.05228973e+20]
#  [-7.70576803e+20]]
# 3 Cost:  inf
# Prediction:
#  [[1.6590036e+28]
#  [3.3397445e+28]
#  [2.6272565e+28]
#  [1.8416928e+28]
#  [2.1705335e+28]
#  [2.1888022e+28]
#  [2.0061132e+28]
#  [2.5541807e+28]]
# 4 Cost:  inf
# Prediction:
#  [[-5.49899185e+35]
#  [-1.10700346e+36]
#  [-8.70839676e+35]
#  [-6.10453983e+35]
#  [-7.19452642e+35]
#  [-7.25508130e+35]
#  [-6.64953332e+35]
#  [-8.46617725e+35]]
# 5 Cost:  inf
# Prediction:
#  [[inf]
#  [inf]
#  [inf]
#  [inf]
#  [inf]
#  [inf]
#  [inf]
#  [inf]]
# 6 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 7 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 8 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 9 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 10 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 11 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 12 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 13 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 14 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 15 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 16 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 17 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 18 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 19 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 20 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 21 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 22 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 23 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 24 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 25 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 26 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 27 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 28 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 29 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 30 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 31 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 32 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 33 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 34 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 35 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 36 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 37 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 38 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 39 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 40 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 41 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 42 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 43 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 44 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 45 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 46 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 47 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 48 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 49 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 50 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 51 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 52 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 53 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 54 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 55 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 56 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 57 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 58 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 59 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 60 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 61 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 62 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 63 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 64 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 65 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 66 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 67 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 68 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 69 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 70 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 71 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 72 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 73 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 74 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 75 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 76 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 77 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 78 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 79 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 80 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 81 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 82 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 83 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 84 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 85 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 86 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 87 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 88 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 89 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 90 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 91 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 92 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 93 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 94 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 95 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 96 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 97 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 98 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 99 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 100 Cost:  nan
# Prediction:
#  [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]

# %% [markdown]
# ### Need to do normalization
# #### from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# #### MinMaxScaler for normalization

# %%
# def MinMaxScaler(data):
#     numerator = data - np.min(data, 0)
#     denominator = np.max(data, 0) - np.min(data, 0)
#     # noise term prevents the zero division
#     return numerator / (denominator + 1e-7)

xy = MinMaxScaler().fit(xy).transform(xy)
print(xy)

x_data = xy[:, 0:-1]
y_data = xy[:, [-1]]
# Out:
# [[1.         1.         0.         1.         1.        ]
#  [0.70548491 0.70439552 1.         0.71881783 0.83755792]
#  [0.54412549 0.50274824 0.57608696 0.60646801 0.6606331 ]
#  [0.33890353 0.31368023 0.10869565 0.45989134 0.43800918]
#  [0.51436    0.4258239  0.30434783 0.58504805 0.42624401]
#  [0.49556179 0.4258239  0.31521739 0.48131134 0.49276137]
#  [0.11436064 0.         0.20652174 0.22007776 0.18597238]
#  [0.         0.07747099 0.5326087  0.         0.        ]]

# %%
# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape=[None, 4])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([4, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# Hypothesis
hypothesis = tf.matmul(X, W) + b

# Simplified cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# Launch the graph in a session.
with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())

        for step in range(101):
            cost_val, hy_val, _ = sess.run([cost, hypothesis, train], 
                                                         feed_dict={X: x_data, Y: y_data})
            print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)
# Out:
# 0 Cost:  3.4385576
# Prediction:
#  [[-1.8153298 ]
#  [-2.2788095 ]
#  [-1.4836807 ]
#  [-0.5715175 ]
#  [-1.0962427 ]
#  [-0.8759355 ]
#  [-0.06291693]
#  [ 0.01290894]]
# 1 Cost:  3.438326
# Prediction:
#  [[-1.8152392 ]
#  [-2.278723  ]
#  [-1.4836092 ]
#  [-0.57146305]
#  [-1.0961773 ]
#  [-0.87587255]
#  [-0.06287664]
#  [ 0.0129481 ]]
# 2 Cost:  3.4380937
# Prediction:
#  [[-1.8151486 ]
#  [-2.2786362 ]
#  [-1.4835377 ]
#  [-0.57140857]
#  [-1.096112  ]
#  [-0.8758097 ]
#  [-0.06283653]
#  [ 0.01298726]]
# 3 Cost:  3.4378617
# Prediction:
#  [[-1.815058  ]
#  [-2.2785494 ]
#  [-1.4834664 ]
#  [-0.5713542 ]
#  [-1.0960467 ]
#  [-0.8757469 ]
#  [-0.06279629]
#  [ 0.01302642]]
# 4 Cost:  3.4376292
# Prediction:
#  [[-1.8149674 ]
#  [-2.278463  ]
#  [-1.4833946 ]
#  [-0.57129985]
#  [-1.0959814 ]
#  [-0.87568384]
#  [-0.06275606]
#  [ 0.01306564]]
# 5 Cost:  3.4373975
# Prediction:
#  [[-1.8148768 ]
#  [-2.278376  ]
#  [-1.4833231 ]
#  [-0.5712454 ]
#  [-1.095916  ]
#  [-0.87562114]
#  [-0.06271595]
#  [ 0.0131048 ]]
# 6 Cost:  3.4371655
# Prediction:
#  [[-1.8147862 ]
#  [-2.2782896 ]
#  [-1.4832516 ]
#  [-0.571191  ]
#  [-1.0958507 ]
#  [-0.8755581 ]
#  [-0.06267565]
#  [ 0.01314396]]
# 7 Cost:  3.4369333
# Prediction:
#  [[-1.8146956 ]
#  [-2.278203  ]
#  [-1.4831803 ]
#  [-0.57113665]
#  [-1.0957854 ]
#  [-0.87549514]
#  [-0.06263548]
#  [ 0.01318312]]
# 8 Cost:  3.4367015
# Prediction:
#  [[-1.814605  ]
#  [-2.2781165 ]
#  [-1.4831088 ]
#  [-0.5710822 ]
#  [-1.09572   ]
#  [-0.8754322 ]
#  [-0.06259525]
#  [ 0.01322228]]
# 9 Cost:  3.4364696
# Prediction:
#  [[-1.8145144 ]
#  [-2.2780297 ]
#  [-1.4830375 ]
#  [-0.5710277 ]
#  [-1.0956547 ]
#  [-0.87536937]
#  [-0.06255507]
#  [ 0.01326144]]
# 10 Cost:  3.4362373
# Prediction:
#  [[-1.8144238 ]
#  [-2.2779431 ]
#  [-1.482966  ]
#  [-0.57097334]
#  [-1.0955894 ]
#  [-0.8753064 ]
#  [-0.06251484]
#  [ 0.01330066]]
# 11 Cost:  3.436005
# Prediction:
#  [[-1.8143332 ]
#  [-2.2778563 ]
#  [-1.4828944 ]
#  [-0.570919  ]
#  [-1.0955241 ]
#  [-0.8752435 ]
#  [-0.06247461]
#  [ 0.01333982]]
# 12 Cost:  3.4357736
# Prediction:
#  [[-1.8142426 ]
#  [-2.2777698 ]
#  [-1.4828229 ]
#  [-0.5708646 ]
#  [-1.0954587 ]
#  [-0.87518066]
#  [-0.06243443]
#  [ 0.01337892]]
# 13 Cost:  3.4355416
# Prediction:
#  [[-1.814152  ]
#  [-2.277683  ]
#  [-1.4827514 ]
#  [-0.57081026]
#  [-1.0953934 ]
#  [-0.8751177 ]
#  [-0.0623942 ]
#  [ 0.01341814]]
# 14 Cost:  3.4353096
# Prediction:
#  [[-1.8140614 ]
#  [-2.2775965 ]
#  [-1.4826801 ]
#  [-0.5707559 ]
#  [-1.0953283 ]
#  [-0.8750548 ]
#  [-0.06235403]
#  [ 0.0134573 ]]
# 15 Cost:  3.435078
# Prediction:
#  [[-1.8139708 ]
#  [-2.27751   ]
#  [-1.4826086 ]
#  [-0.57070154]
#  [-1.0952628 ]
#  [-0.87499183]
#  [-0.06231385]
#  [ 0.01349652]]
# 16 Cost:  3.4348457
# Prediction:
#  [[-1.8138802 ]
#  [-2.2774234 ]
#  [-1.482537  ]
#  [-0.57064706]
#  [-1.0951974 ]
#  [-0.874929  ]
#  [-0.06227356]
#  [ 0.01353562]]
# 17 Cost:  3.4346142
# Prediction:
#  [[-1.8137896 ]
#  [-2.2773368 ]
#  [-1.4824655 ]
#  [-0.5705926 ]
#  [-1.0951324 ]
#  [-0.87486607]
#  [-0.06223345]
#  [ 0.01357478]]
# 18 Cost:  3.434382
# Prediction:
#  [[-1.813699  ]
#  [-2.27725   ]
#  [-1.482394  ]
#  [-0.5705382 ]
#  [-1.0950668 ]
#  [-0.8748031 ]
#  [-0.06219316]
#  [ 0.013614  ]]
# 19 Cost:  3.4341497
# Prediction:
#  [[-1.8136084 ]
#  [-2.2771633 ]
#  [-1.4823225 ]
#  [-0.57048386]
#  [-1.0950015 ]
#  [-0.8747403 ]
#  [-0.06215298]
#  [ 0.01365316]]
# 20 Cost:  3.4339178
# Prediction:
#  [[-1.8135178 ]
#  [-2.2770767 ]
#  [-1.4822509 ]
#  [-0.5704294 ]
#  [-1.0949361 ]
#  [-0.87467736]
#  [-0.06211287]
#  [ 0.01369232]]
# 21 Cost:  3.4336863
# Prediction:
#  [[-1.8134272 ]
#  [-2.27699   ]
#  [-1.4821796 ]
#  [-0.570375  ]
#  [-1.094871  ]
#  [-0.87461454]
#  [-0.06207258]
#  [ 0.01373148]]
# 22 Cost:  3.4334545
# Prediction:
#  [[-1.8133366 ]
#  [-2.2769036 ]
#  [-1.4821081 ]
#  [-0.57032067]
#  [-1.0948055 ]
#  [-0.8745515 ]
#  [-0.0620324 ]
#  [ 0.01377064]]
# 23 Cost:  3.4332223
# Prediction:
#  [[-1.813246  ]
#  [-2.2768168 ]
#  [-1.4820366 ]
#  [-0.5702662 ]
#  [-1.0947404 ]
#  [-0.87448865]
#  [-0.06199211]
#  [ 0.01380986]]
# 24 Cost:  3.4329906
# Prediction:
#  [[-1.8131554 ]
#  [-2.2767305 ]
#  [-1.4819651 ]
#  [-0.5702118 ]
#  [-1.0946751 ]
#  [-0.8744258 ]
#  [-0.06195199]
#  [ 0.01384902]]
# 25 Cost:  3.4327588
# Prediction:
#  [[-1.8130648 ]
#  [-2.2766438 ]
#  [-1.4818935 ]
#  [-0.57015747]
#  [-1.0946097 ]
#  [-0.87436277]
#  [-0.06191176]
#  [ 0.01388818]]
# 26 Cost:  3.432527
# Prediction:
#  [[-1.8129742 ]
#  [-2.2765572 ]
#  [-1.481822  ]
#  [-0.570103  ]
#  [-1.0945446 ]
#  [-0.87429994]
#  [-0.06187153]
#  [ 0.01392734]]
# 27 Cost:  3.432295
# Prediction:
#  [[-1.8128836 ]
#  [-2.2764704 ]
#  [-1.4817505 ]
#  [-0.5700485 ]
#  [-1.0944791 ]
#  [-0.8742371 ]
#  [-0.06183136]
#  [ 0.0139665 ]]
# 28 Cost:  3.432063
# Prediction:
#  [[-1.812793  ]
#  [-2.2763836 ]
#  [-1.481679  ]
#  [-0.56999415]
#  [-1.094414  ]
#  [-0.87417406]
#  [-0.06179112]
#  [ 0.01400566]]
# 29 Cost:  3.4318314
# Prediction:
#  [[-1.8127024 ]
#  [-2.276297  ]
#  [-1.4816074 ]
#  [-0.5699399 ]
#  [-1.0943487 ]
#  [-0.8741111 ]
#  [-0.06175095]
#  [ 0.01404488]]
# 30 Cost:  3.4315999
# Prediction:
#  [[-1.8126118 ]
#  [-2.2762105 ]
#  [-1.4815361 ]
#  [-0.56988543]
#  [-1.0942833 ]
#  [-0.8740484 ]
#  [-0.06171077]
#  [ 0.01408404]]
# 31 Cost:  3.4313679
# Prediction:
#  [[-1.8125212 ]
#  [-2.276124  ]
#  [-1.4814649 ]
#  [-0.5698311 ]
#  [-1.094218  ]
#  [-0.87398535]
#  [-0.06167048]
#  [ 0.01412314]]
# 32 Cost:  3.4311364
# Prediction:
#  [[-1.8124306 ]
#  [-2.2760375 ]
#  [-1.4813933 ]
#  [-0.5697767 ]
#  [-1.0941527 ]
#  [-0.8739225 ]
#  [-0.06163031]
#  [ 0.01416236]]
# 33 Cost:  3.4309044
# Prediction:
#  [[-1.81234   ]
#  [-2.2759507 ]
#  [-1.4813218 ]
#  [-0.56972224]
#  [-1.0940874 ]
#  [-0.8738597 ]
#  [-0.06159008]
#  [ 0.01420152]]
# 34 Cost:  3.4306724
# Prediction:
#  [[-1.8122494 ]
#  [-2.2758641 ]
#  [-1.4812503 ]
#  [-0.5696679 ]
#  [-1.094022  ]
#  [-0.8737969 ]
#  [-0.0615499 ]
#  [ 0.01424074]]
# 35 Cost:  3.430441
# Prediction:
#  [[-1.8121591 ]
#  [-2.2757773 ]
#  [-1.4811788 ]
#  [-0.5696135 ]
#  [-1.0939567 ]
#  [-0.8737338 ]
#  [-0.06150973]
#  [ 0.01427984]]
# 36 Cost:  3.4302092
# Prediction:
#  [[-1.8120685 ]
#  [-2.2756908 ]
#  [-1.4811072 ]
#  [-0.5695592 ]
#  [-1.0938915 ]
#  [-0.87367094]
#  [-0.06146955]
#  [ 0.01431894]]
# 37 Cost:  3.4299774
# Prediction:
#  [[-1.8119779 ]
#  [-2.275604  ]
#  [-1.481036  ]
#  [-0.5695048 ]
#  [-1.093826  ]
#  [-0.8736082 ]
#  [-0.06142944]
#  [ 0.0143581 ]]
# 38 Cost:  3.429746
# Prediction:
#  [[-1.8118874 ]
#  [-2.2755175 ]
#  [-1.4809645 ]
#  [-0.5694505 ]
#  [-1.093761  ]
#  [-0.8735453 ]
#  [-0.06138921]
#  [ 0.0143972 ]]
# 39 Cost:  3.4295144
# Prediction:
#  [[-1.8117969 ]
#  [-2.2754312 ]
#  [-1.4808931 ]
#  [-0.5693962 ]
#  [-1.0936956 ]
#  [-0.8734824 ]
#  [-0.06134915]
#  [ 0.0144363 ]]
# 40 Cost:  3.4292834
# Prediction:
#  [[-1.8117063 ]
#  [-2.2753446 ]
#  [-1.4808216 ]
#  [-0.5693419 ]
#  [-1.0936304 ]
#  [-0.87341976]
#  [-0.06130898]
#  [ 0.01447541]]
# 41 Cost:  3.4290516
# Prediction:
#  [[-1.8116157 ]
#  [-2.275258  ]
#  [-1.4807503 ]
#  [-0.56928736]
#  [-1.0935652 ]
#  [-0.87335676]
#  [-0.06126881]
#  [ 0.01451451]]
# 42 Cost:  3.4288204
# Prediction:
#  [[-1.8115252 ]
#  [-2.2751718 ]
#  [-1.4806789 ]
#  [-0.56923306]
#  [-1.0935    ]
#  [-0.8732939 ]
#  [-0.06122869]
#  [ 0.01455367]]
# 43 Cost:  3.4285889
# Prediction:
#  [[-1.8114347 ]
#  [-2.275085  ]
#  [-1.4806075 ]
#  [-0.56917876]
#  [-1.0934348 ]
#  [-0.87323123]
#  [-0.06118852]
#  [ 0.01459277]]
# 44 Cost:  3.4283571
# Prediction:
#  [[-1.8113441 ]
#  [-2.2749984 ]
#  [-1.480536  ]
#  [-0.56912434]
#  [-1.0933695 ]
#  [-0.87316823]
#  [-0.06114835]
#  [ 0.01463187]]
# 45 Cost:  3.4281259
# Prediction:
#  [[-1.8112538 ]
#  [-2.2749116 ]
#  [-1.4804645 ]
#  [-0.56907004]
#  [-1.0933044 ]
#  [-0.87310547]
#  [-0.06110829]
#  [ 0.01467097]]
# 46 Cost:  3.427894
# Prediction:
#  [[-1.8111633 ]
#  [-2.274825  ]
#  [-1.480393  ]
#  [-0.56901586]
#  [-1.093239  ]
#  [-0.8730426 ]
#  [-0.06106806]
#  [ 0.01471007]]
# 47 Cost:  3.4276633
# Prediction:
#  [[-1.8110728 ]
#  [-2.2747388 ]
#  [-1.4803219 ]
#  [-0.56896156]
#  [-1.0931737 ]
#  [-0.87297994]
#  [-0.06102794]
#  [ 0.01474917]]
# 48 Cost:  3.4274313
# Prediction:
#  [[-1.8109822 ]
#  [-2.274652  ]
#  [-1.4802504 ]
#  [-0.56890714]
#  [-1.0931085 ]
#  [-0.87291706]
#  [-0.06098777]
#  [ 0.01478833]]
# 49 Cost:  3.4272
# Prediction:
#  [[-1.8108916 ]
#  [-2.2745657 ]
#  [-1.4801788 ]
#  [-0.56885284]
#  [-1.0930433 ]
#  [-0.8728542 ]
#  [-0.06094766]
#  [ 0.01482737]]
# 50 Cost:  3.426969
# Prediction:
#  [[-1.8108014 ]
#  [-2.2744794 ]
#  [-1.4801074 ]
#  [-0.56879854]
#  [-1.092978  ]
#  [-0.8727913 ]
#  [-0.06090754]
#  [ 0.01486653]]
# 51 Cost:  3.4267378
# Prediction:
#  [[-1.8107109 ]
#  [-2.2743926 ]
#  [-1.4800363 ]
#  [-0.5687441 ]
#  [-1.0929129 ]
#  [-0.8727285 ]
#  [-0.06086737]
#  [ 0.01490563]]
# 52 Cost:  3.4265063
# Prediction:
#  [[-1.8106203 ]
#  [-2.274306  ]
#  [-1.4799647 ]
#  [-0.5686898 ]
#  [-1.0928476 ]
#  [-0.87266564]
#  [-0.06082726]
#  [ 0.01494473]]
# 53 Cost:  3.4262748
# Prediction:
#  [[-1.8105297 ]
#  [-2.2742193 ]
#  [-1.4798934 ]
#  [-0.56863564]
#  [-1.0927823 ]
#  [-0.8726029 ]
#  [-0.06078708]
#  [ 0.01498383]]
# 54 Cost:  3.4260435
# Prediction:
#  [[-1.8104395 ]
#  [-2.2741327 ]
#  [-1.479822  ]
#  [-0.5685812 ]
#  [-1.0927172 ]
#  [-0.8725401 ]
#  [-0.06074691]
#  [ 0.01502293]]
# 55 Cost:  3.4258122
# Prediction:
#  [[-1.810349  ]
#  [-2.2740464 ]
#  [-1.4797504 ]
#  [-0.5685269 ]
#  [-1.0926521 ]
#  [-0.87247723]
#  [-0.06070679]
#  [ 0.01506203]]
# 56 Cost:  3.425581
# Prediction:
#  [[-1.8102584 ]
#  [-2.2739599 ]
#  [-1.4796793 ]
#  [-0.5684726 ]
#  [-1.0925868 ]
#  [-0.87241435]
#  [-0.06066668]
#  [ 0.01510119]]
# 57 Cost:  3.4253502
# Prediction:
#  [[-1.8101678 ]
#  [-2.2738736 ]
#  [-1.4796078 ]
#  [-0.5684183 ]
#  [-1.0925217 ]
#  [-0.8723516 ]
#  [-0.06062651]
#  [ 0.01514024]]
# 58 Cost:  3.425119
# Prediction:
#  [[-1.8100775 ]
#  [-2.273787  ]
#  [-1.4795364 ]
#  [-0.5683639 ]
#  [-1.0924563 ]
#  [-0.8722888 ]
#  [-0.06058639]
#  [ 0.01517934]]
# 59 Cost:  3.4248877
# Prediction:
#  [[-1.8099871 ]
#  [-2.2737005 ]
#  [-1.479465  ]
#  [-0.5683096 ]
#  [-1.092391  ]
#  [-0.87222594]
#  [-0.06054622]
#  [ 0.0152185 ]]
# 60 Cost:  3.424656
# Prediction:
#  [[-1.8098965 ]
#  [-2.2736137 ]
#  [-1.4793935 ]
#  [-0.5682553 ]
#  [-1.0923259 ]
#  [-0.87216306]
#  [-0.06050611]
#  [ 0.0152576 ]]
# 61 Cost:  3.4244246
# Prediction:
#  [[-1.8098061 ]
#  [-2.2735271 ]
#  [-1.4793222 ]
#  [-0.568201  ]
#  [-1.0922606 ]
#  [-0.8721004 ]
#  [-0.06046593]
#  [ 0.0152967 ]]
# 62 Cost:  3.4241936
# Prediction:
#  [[-1.8097156 ]
#  [-2.2734408 ]
#  [-1.4792508 ]
#  [-0.5681466 ]
#  [-1.0921955 ]
#  [-0.87203753]
#  [-0.06042582]
#  [ 0.0153358 ]]
# 63 Cost:  3.4239626
# Prediction:
#  [[-1.8096251 ]
#  [-2.2733543 ]
#  [-1.4791794 ]
#  [-0.5680924 ]
#  [-1.0921302 ]
#  [-0.87197477]
#  [-0.06038558]
#  [ 0.0153749 ]]
# 64 Cost:  3.423731
# Prediction:
#  [[-1.8095345 ]
#  [-2.2732677 ]
#  [-1.4791081 ]
#  [-0.5680381 ]
#  [-1.092065  ]
#  [-0.871912  ]
#  [-0.06034553]
#  [ 0.01541406]]
# 65 Cost:  3.4235003
# Prediction:
#  [[-1.8094442 ]
#  [-2.2731812 ]
#  [-1.4790368 ]
#  [-0.5679838 ]
#  [-1.0919998 ]
#  [-0.871849  ]
#  [-0.06030542]
#  [ 0.0154531 ]]
# 66 Cost:  3.4232688
# Prediction:
#  [[-1.8093537 ]
#  [-2.2730947 ]
#  [-1.4789654 ]
#  [-0.5679294 ]
#  [-1.0919346 ]
#  [-0.8717861 ]
#  [-0.06026518]
#  [ 0.0154922 ]]
# 67 Cost:  3.423038
# Prediction:
#  [[-1.8092632 ]
#  [-2.2730083 ]
#  [-1.478894  ]
#  [-0.5678751 ]
#  [-1.0918694 ]
#  [-0.87172335]
#  [-0.06022513]
#  [ 0.01553136]]
# 68 Cost:  3.4228065
# Prediction:
#  [[-1.8091729 ]
#  [-2.2729216 ]
#  [-1.4788225 ]
#  [-0.5678208 ]
#  [-1.091804  ]
#  [-0.8716606 ]
#  [-0.06018496]
#  [ 0.01557046]]
# 69 Cost:  3.4225752
# Prediction:
#  [[-1.8090823 ]
#  [-2.272835  ]
#  [-1.478751  ]
#  [-0.5677665 ]
#  [-1.0917389 ]
#  [-0.8715978 ]
#  [-0.06014478]
#  [ 0.01560956]]
# 70 Cost:  3.4223442
# Prediction:
#  [[-1.8089918 ]
#  [-2.2727485 ]
#  [-1.4786798 ]
#  [-0.5677122 ]
#  [-1.0916737 ]
#  [-0.87153494]
#  [-0.06010467]
#  [ 0.01564866]]
# 71 Cost:  3.4221134
# Prediction:
#  [[-1.8089015 ]
#  [-2.2726622 ]
#  [-1.4786084 ]
#  [-0.5676579 ]
#  [-1.0916083 ]
#  [-0.8714723 ]
#  [-0.06006449]
#  [ 0.01568776]]
# 72 Cost:  3.4218822
# Prediction:
#  [[-1.808811  ]
#  [-2.2725756 ]
#  [-1.4785368 ]
#  [-0.56760347]
#  [-1.0915432 ]
#  [-0.8714094 ]
#  [-0.06002438]
#  [ 0.01572692]]
# 73 Cost:  3.4216506
# Prediction:
#  [[-1.8087204 ]
#  [-2.272489  ]
#  [-1.4784653 ]
#  [-0.56754917]
#  [-1.0914781 ]
#  [-0.87134653]
#  [-0.05998427]
#  [ 0.01576596]]
# 74 Cost:  3.4214196
# Prediction:
#  [[-1.8086301 ]
#  [-2.2724028 ]
#  [-1.4783942 ]
#  [-0.56749487]
#  [-1.0914128 ]
#  [-0.87128365]
#  [-0.05994403]
#  [ 0.01580507]]
# 75 Cost:  3.4211888
# Prediction:
#  [[-1.8085396 ]
#  [-2.272316  ]
#  [-1.478323  ]
#  [-0.56744057]
#  [-1.0913475 ]
#  [-0.8712209 ]
#  [-0.05990398]
#  [ 0.01584423]]
# 76 Cost:  3.4209576
# Prediction:
#  [[-1.808449  ]
#  [-2.2722294 ]
#  [-1.4782512 ]
#  [-0.56738615]
#  [-1.0912822 ]
#  [-0.8711581 ]
#  [-0.05986381]
#  [ 0.01588333]]
# 77 Cost:  3.420726
# Prediction:
#  [[-1.8083584 ]
#  [-2.272143  ]
#  [-1.4781797 ]
#  [-0.56733185]
#  [-1.091217  ]
#  [-0.87109524]
#  [-0.05982363]
#  [ 0.01592237]]
# 78 Cost:  3.420495
# Prediction:
#  [[-1.8082682 ]
#  [-2.272056  ]
#  [-1.4781085 ]
#  [-0.56727755]
#  [-1.0911518 ]
#  [-0.8710325 ]
#  [-0.05978346]
#  [ 0.01596153]]
# 79 Cost:  3.4202642
# Prediction:
#  [[-1.8081777 ]
#  [-2.2719698 ]
#  [-1.4780374 ]
#  [-0.56722325]
#  [-1.0910866 ]
#  [-0.8709696 ]
#  [-0.0597434 ]
#  [ 0.01600063]]
# 80 Cost:  3.420033
# Prediction:
#  [[-1.8080871 ]
#  [-2.2718835 ]
#  [-1.4779658 ]
#  [-0.56716895]
#  [-1.0910214 ]
#  [-0.87090683]
#  [-0.05970323]
#  [ 0.01603979]]
# 81 Cost:  3.419802
# Prediction:
#  [[-1.8079967 ]
#  [-2.2717967 ]
#  [-1.4778943 ]
#  [-0.56711465]
#  [-1.0909562 ]
#  [-0.87084395]
#  [-0.05966306]
#  [ 0.01607889]]
# 82 Cost:  3.4195714
# Prediction:
#  [[-1.8079063 ]
#  [-2.2717104 ]
#  [-1.4778231 ]
#  [-0.5670605 ]
#  [-1.090891  ]
#  [-0.8707813 ]
#  [-0.059623  ]
#  [ 0.01611793]]
# 83 Cost:  3.4193406
# Prediction:
#  [[-1.8078158 ]
#  [-2.2716238 ]
#  [-1.4777517 ]
#  [-0.5670061 ]
#  [-1.0908258 ]
#  [-0.8707185 ]
#  [-0.05958283]
#  [ 0.01615703]]
# 84 Cost:  3.4191093
# Prediction:
#  [[-1.8077255 ]
#  [-2.2715373 ]
#  [-1.4776803 ]
#  [-0.5669519 ]
#  [-1.0907606 ]
#  [-0.87065566]
#  [-0.05954278]
#  [ 0.01619607]]
# 85 Cost:  3.4188786
# Prediction:
#  [[-1.8076351 ]
#  [-2.271451  ]
#  [-1.4776089 ]
#  [-0.56689763]
#  [-1.0906955 ]
#  [-0.8705931 ]
#  [-0.05950272]
#  [ 0.01623511]]
# 86 Cost:  3.4186478
# Prediction:
#  [[-1.8075448 ]
#  [-2.2713642 ]
#  [-1.4775378 ]
#  [-0.5668434 ]
#  [-1.0906304 ]
#  [-0.87053025]
#  [-0.05946267]
#  [ 0.01627415]]
# 87 Cost:  3.4184172
# Prediction:
#  [[-1.8074543 ]
#  [-2.271278  ]
#  [-1.4774666 ]
#  [-0.56678903]
#  [-1.0905653 ]
#  [-0.87046754]
#  [-0.05942249]
#  [ 0.0163132 ]]
# 88 Cost:  3.4181864
# Prediction:
#  [[-1.8073639 ]
#  [-2.2711916 ]
#  [-1.4773952 ]
#  [-0.5667348 ]
#  [-1.0905002 ]
#  [-0.87040484]
#  [-0.0593825 ]
#  [ 0.0163523 ]]
# 89 Cost:  3.4179559
# Prediction:
#  [[-1.8072736 ]
#  [-2.271105  ]
#  [-1.477324  ]
#  [-0.56668055]
#  [-1.0904349 ]
#  [-0.870342  ]
#  [-0.05934244]
#  [ 0.01639128]]
# 90 Cost:  3.417725
# Prediction:
#  [[-1.8071831 ]
#  [-2.271019  ]
#  [-1.4772526 ]
#  [-0.5666263 ]
#  [-1.0903698 ]
#  [-0.8702792 ]
#  [-0.05930227]
#  [ 0.01643032]]
# 91 Cost:  3.4174943
# Prediction:
#  [[-1.8070927 ]
#  [-2.2709324 ]
#  [-1.4771812 ]
#  [-0.56657207]
#  [-1.0903047 ]
#  [-0.87021637]
#  [-0.05926222]
#  [ 0.01646942]]
# 92 Cost:  3.4172635
# Prediction:
#  [[-1.8070024 ]
#  [-2.270846  ]
#  [-1.4771098 ]
#  [-0.56651783]
#  [-1.0902395 ]
#  [-0.8701538 ]
#  [-0.05922216]
#  [ 0.01650846]]
# 93 Cost:  3.417033
# Prediction:
#  [[-1.806912  ]
#  [-2.2707593 ]
#  [-1.4770386 ]
#  [-0.5664635 ]
#  [-1.0901744 ]
#  [-0.8700911 ]
#  [-0.05918205]
#  [ 0.01654744]]
# 94 Cost:  3.4168022
# Prediction:
#  [[-1.8068217 ]
#  [-2.2706728 ]
#  [-1.4769672 ]
#  [-0.56640923]
#  [-1.0901092 ]
#  [-0.87002826]
#  [-0.05914193]
#  [ 0.01658654]]
# 95 Cost:  3.4165714
# Prediction:
#  [[-1.8067312 ]
#  [-2.2705865 ]
#  [-1.4768958 ]
#  [-0.566355  ]
#  [-1.0900441 ]
#  [-0.8699657 ]
#  [-0.05910188]
#  [ 0.01662558]]
# 96 Cost:  3.4163413
# Prediction:
#  [[-1.806641  ]
#  [-2.2705002 ]
#  [-1.4768246 ]
#  [-0.56630087]
#  [-1.0899789 ]
#  [-0.86990285]
#  [-0.05906177]
#  [ 0.01666468]]
# 97 Cost:  3.4161105
# Prediction:
#  [[-1.8065505 ]
#  [-2.2704136 ]
#  [-1.4767532 ]
#  [-0.5662466 ]
#  [-1.0899138 ]
#  [-0.86984   ]
#  [-0.05902171]
#  [ 0.01670367]]
# 98 Cost:  3.4158797
# Prediction:
#  [[-1.8064603 ]
#  [-2.2703276 ]
#  [-1.4766818 ]
#  [-0.5661924 ]
#  [-1.0898488 ]
#  [-0.8697773 ]
#  [-0.05898166]
#  [ 0.01674271]]
# 99 Cost:  3.415649
# Prediction:
#  [[-1.8063698 ]
#  [-2.270241  ]
#  [-1.4766107 ]
#  [-0.56613815]
#  [-1.0897834 ]
#  [-0.8697146 ]
#  [-0.05894154]
#  [ 0.01678181]]
# 100 Cost:  3.4154184
# Prediction:
#  [[-1.8062795 ]
#  [-2.2701545 ]
#  [-1.4765393 ]
#  [-0.5660839 ]
#  [-1.0897183 ]
#  [-0.8696519 ]
#  [-0.05890149]
#  [ 0.01682079]]

# %%
"""

tensorflow as normalization function
tf.nn.batch_normalization(x, mean, variance, offset, scale, variance_epsilon, name=None)
x: Input Tensor of arbitrary dimensionality.
mean: A mean Tensor.
variance: A variance Tensor.
offset: An offset Tensor, often denoted \(\beta\) in equations, or None. If present, will be added to the normalized tensor.
scale: A scale Tensor, often denoted \(\gamma\) in equations, or None. If present, the scale is applied to the normalized tensor.
variance_epsilon: A small float number to avoid dividing by 0.
name: A name for this operation (optional).

"""



def MinMaxScaler2(data):
    numerator = data - np.min(data, 0)
    denominator = np.max(data, 0) - np.min(data, 0)
    # noise term prevents the zero division
    return numerator / (denominator + 1e-7)


import tensorflow as tf
import numpy as np
from sklearn.preprocessing import MinMaxScaler

data = np.array([[828.659973, 833.450012, 908100, 828.349976, 831.659973],
               [823.02002, 828.070007, 1828100, 821.655029, 828.070007],
               [819.929993, 824.400024, 1438100, 818.97998, 824.159973],
               [816, 820.958984, 1008100, 815.48999, 819.23999],
               [819.359985, 823, 1188100, 818.469971, 818.97998],
               [819, 823, 1198100, 816, 820.450012],
               [811.700012, 815.25, 1098100, 809.780029, 813.669983],
               [809.51001, 816.659973, 1398100, 804.539978, 809.559998]])

x = tf.placeholder(tf.float32, [None, 5])
W = tf.Variable(tf.random_normal([5, 1]), name='weight')
print(W.shape)
b = tf.Variable(tf.random_normal([1]), name='bias')

y = tf.matmul(x, W) + b

mean, variance = tf.nn.moments(y, axes=[0])
scale = tf.Variable(tf.ones([1]))
beta = tf.Variable(tf.zeros([1]))
epsilon = 1e-3


BN = tf.nn.batch_normalization(data, mean, variance, None, None, epsilon)
print(BN.shape)
# Out:
# (5, 1)
# (8, 5)

# %%
def normalization(data):
  mean = np.mean(data)
  variance = np.var(data)
  
  print("mean:", mean)
  print("variance:",variance)
  
  return (data - mean) / np.sqrt(variance**2 + 1e-4)

data = np.array([[828.659973, 833.450012, 908100, 828.349976, 831.659973],
               [823.02002, 828.070007, 1828100, 821.655029, 828.070007],
               [819.929993, 824.400024, 1438100, 818.97998, 824.159973],
               [816, 820.958984, 1008100, 815.48999, 819.23999],
               [819.359985, 823, 1188100, 818.469971, 818.97998],
               [819, 823, 1198100, 816, 820.450012],
               [811.700012, 815.25, 1098100, 809.780029, 813.669983],
               [809.51001, 816.659973, 1398100, 804.539978, 809.559998]])
normalization(data)


data = np.random.normal(0, 1, 25).reshape(-1, 5)
print(data, "\n")
print(normalization(data))
print(MinMaxScaler2(data))

data = MinMaxScaler().fit(data).transform(data)
print(data)
# Out:
# mean: 252275.77559655003
# variance: 267820592634.72247
# [[-1.60235511e+00 -1.49428601e+00  8.28941399e-04 -3.59892323e-01
#    8.47913270e-02]
#  [-4.20168231e-01  7.44450521e-01 -5.87524795e-01  9.25248426e-01
#   -4.51453577e-01]
#  [ 1.99738413e+00  2.07061529e+00  9.69783647e-01  8.37881077e-01
#   -9.43005456e-01]
#  [-9.90967216e-03 -1.89058110e-01 -1.68581952e+00  1.42683092e+00
#   -9.64709732e-01]
#  [ 3.32121876e-01  9.82039278e-01 -1.92135106e+00  1.55540553e+00
#   -8.43877603e-01]]
#
# mean: 0.01815879070428815
# variance: 1.2646222832470273
# [[-1.28138122 -1.19592825 -0.01370315 -0.29893455  0.05268803]
#  [-0.34659623  0.57429719 -0.47892929  0.71725865 -0.37133434]
#  [ 1.56502339  1.62292912  0.75247378  0.64817509 -0.76001681]
#  [-0.02219444 -0.16385163 -1.34737863  1.11387258 -0.77717893]
#  [ 0.24825853  0.76216461 -1.53361936  1.21553977 -0.68163392]]
# [[0.         0.         0.66485312 0.         0.9999999 ]
#  [0.32840902 0.62799396 0.46135042 0.67098738 0.48904773]
#  [0.99999997 0.99999997 0.99999997 0.62537184 0.02068056]
#  [0.44237799 0.36613296 0.08146681 0.9328696  0.        ]
#  [0.53739363 0.69464061 0.         0.99999995 0.11513292]]
# [[0.         0.         0.66485314 0.         1.        ]
#  [0.32840903 0.62799397 0.46135044 0.67098741 0.48904777]
#  [1.         1.         1.         0.62537187 0.02068057]
#  [0.442378   0.36613297 0.08146682 0.93286965 0.        ]
#  [0.53739364 0.69464063 0.         1.         0.11513293]]
